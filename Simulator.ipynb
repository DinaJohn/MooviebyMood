# %% [markdown]
# # Assigning Moods to Users

# %%
import pandas as pd
import numpy as np
import random

ratings_df = pd.read_csv("movielens_dataset/ratings.csv")

def assign_mood():
    possible_moods = ['Joy', 'Sadness', 'Anger', 'Fear', 'Disgust']
    return random.choice(possible_moods)

user_profiles = {}
mood_counter = {'Joy': 0, 'Sadness': 0, 'Anger': 0, 'Fear': 0, 'Disgust': 0}

for user_id in ratings_df['userId'].unique():
    user_ratings = ratings_df[ratings_df['userId'] == user_id]
    mood = assign_mood()
    preferred_movies = user_ratings[user_ratings['rating'] >= 4]['movieId'].tolist()

    user_profiles[user_id] = {
        'mood': mood,
        'preferred_movies': preferred_movies
    }
    
    mood_counter[mood] += 1

print(mood_counter)
# Out:
# {'Joy': 110, 'Sadness': 117, 'Anger': 109, 'Fear': 150, 'Disgust': 124}

# %% [markdown]
# # Find the features for the movie and the user to predicts users feedback

# %%
from sklearn.metrics.pairwise import cosine_similarity
from joblib import load

# Retrieving data from the MovieLens csv files
ratings = pd.read_csv("movielens_dataset/ratings.csv")
movies = pd.read_csv("movielens_dataset/movies.csv")
tags = pd.read_csv("movielens_dataset/tags.csv")

# User-item matrix creation
user_movie_matrix = ratings.pivot_table(index='userId', columns='movieId', values='rating').fillna(0)

# Calculation of the similarity matrix between users
user_similarity_matrix = cosine_similarity(user_movie_matrix)
user_similarity_df = pd.DataFrame(user_similarity_matrix, index=user_movie_matrix.index, columns=user_movie_matrix.index)

# Compute the similarity matrix between movies
item_similarity_matrix = cosine_similarity(user_movie_matrix.T)
item_similarity_df = pd.DataFrame(item_similarity_matrix, index=user_movie_matrix.columns, columns=user_movie_matrix.columns)

user_means = user_movie_matrix.mean(axis=1)
ratings_for_avg = ratings.merge(movies, on='movieId')
genres_for_avg = ratings_for_avg['genres'].str.split('|', expand=True)
merged_df = pd.concat([ratings_for_avg, genres_for_avg], axis=1)
genres_long = pd.melt(merged_df, id_vars=['userId', 'movieId', 'title','rating', 'timestamp', 'genres'], value_vars=list(genres_for_avg.columns))
average_rating_per_genre = genres_long.groupby('value')['rating'].mean()
genres_long.dropna(inplace=True)

# Get top N similar users for a given user
def get_top_similar_users(similarity_df, user_id, top_n):
    user_similarities = similarity_df.loc[user_id]
    top_users = user_similarities.sort_values(ascending=False).head(top_n).index
    return top_users

# Get top N similar movies for a given movie
def get_top_similar_movies(similarity_df, movie_id, top_n):
    movie_similarities = similarity_df.loc[movie_id]
    top_movies = movie_similarities.sort_values(ascending=False).head(top_n).index
    return top_movies
    
# Calculate the average of user means
def average_user_means(users):
    return user_means.loc[users].mean()

# Calculate the average rating if there are ratings
def calculate_average_rating(similar_movies_ids, all_ratings_df):
    similar_movies_ratings = all_ratings_df[all_ratings_df['movieId'].isin(similar_movies_ids)]
    
    if not similar_movies_ratings.empty:
        return similar_movies_ratings['rating'].mean()
    else:
        return np.nan

# Calculate the average of user means
def average_user_means(users):
    return user_means.loc[users].mean()

# Calculate weighted average rating for each row
def calculate_weighted_avg(row):
    genres = row[8:]  
    valid_genres = [genre for genre in genres if genre in average_rating_per_genre]  
    if valid_genres:
        sum_ratings = sum(average_rating_per_genre[genre] for genre in valid_genres if genre)
        count_genres = len([genre for genre in row[6:] if genre in average_rating_per_genre and genre])
        return sum_ratings / count_genres if count_genres > 0 else 0
    else:
        return 0  

# Use all the function above to find features in particular movie, ratings and user for feedback predictor
def feature_extractor(user_id, movie_id, ratings_df, movies_df, tags_df, user_similarity_df, item_similarity_df):
    feature_dict = {}

    top_similar_users = get_top_similar_users(user_similarity_df, user_id, 5)
    feature_dict['top_similar_users'] = top_similar_users
    
    if movie_id not in item_similarity_df.index:
        try:
            top_similar_movies = get_top_similar_movies(item_similarity_df, movie_id, 1)
            feature_dict['top_similar_movies'] = top_similar_movies
            avg_rating_similar_movies = calculate_average_rating(top_similar_movies, ratings_df)
            feature_dict['avg_rating_of_similar_movies'] = avg_rating_similar_movies
        except Exception as e:
            feature_dict['top_similar_movies'] = None
            feature_dict['avg_rating_of_similar_movies'] = 0
    else:
        top_similar_movies = get_top_similar_movies(item_similarity_df, movie_id, 5)
        feature_dict['top_similar_movies'] = top_similar_movies
        avg_rating_similar_movies = calculate_average_rating(top_similar_movies, ratings_df)
        feature_dict['avg_rating_of_similar_movies'] = avg_rating_similar_movies

    feature_dict['avg_rating_similar_users'] = average_user_means(feature_dict['top_similar_users'])

    user_data = ratings_df[ratings_df['userId'] == user_id]
    movie_data = movies_df[movies_df['movieId'] == movie_id]
    
    user_ratings = ratings_df[ratings_df['userId'] == user_id]
    movie_ratings = ratings_df[ratings_df['movieId'] == movie_id]
    user_movie_rating = user_ratings[user_ratings['movieId'] == movie_id]

    feature_dict['user_avg_rating'] = user_ratings['rating'].mean() if not user_ratings.empty else ratings_df['rating'].mean()
    feature_dict['user_rating_count'] = user_ratings.shape[0]

    feature_dict['movie_avg_rating'] = movie_ratings['rating'].mean() if not movie_ratings.empty else ratings_df['rating'].mean()
    feature_dict['movie_rating_count'] = movie_ratings.shape[0]
    
    genres_df = movies_df['genres'].str.get_dummies(sep='|')
    movie_genres = genres_df.loc[movie_id] if movie_id in genres_df.index else pd.Series([0] * genres_df.shape[1], index=genres_df.columns)
    feature_dict.update(movie_genres.to_dict())

    if not user_movie_rating.empty:
        feature_dict['timestamp'] = user_movie_rating['timestamp'].max()
    else:
        if not movie_ratings.empty:
            feature_dict['timestamp'] = movie_ratings['timestamp'].mean()
        else:
            feature_dict['timestamp'] = pd.Timestamp.now().timestamp()
    
    datetime_obj = pd.to_datetime(feature_dict['timestamp'], unit='s')
    feature_dict['hour'] = datetime_obj.hour
    feature_dict['day_of_week'] = datetime_obj.dayofweek
    feature_dict['day'] = datetime_obj.day
    feature_dict['month'] = datetime_obj.month
    feature_dict['year'] = datetime_obj.year
    
    feature_dict['interaction_movie_user'] = feature_dict['user_avg_rating'] * feature_dict['user_rating_count']
    
    aggregated_tags = tags_df[(tags_df['movieId'] == movie_id)]['tag'].tolist()
    feature_dict['tag_count'] = len(aggregated_tags)

    feature_dict['interaction_movie_user'] = feature_dict['movie_avg_rating'] * feature_dict['user_rating_count']
    feature_dict['user_rating_count_squared'] = feature_dict['user_rating_count'] ** 2

    feature_dict['movieId'] = movie_id
    feature_dict['userId'] = user_id

    movie_genres_list = movies_df.loc[movies_df['movieId'] == movie_id, 'genres'].str.split('|').values
    if movie_genres_list.size > 0:
        feature_dict['num_genres'] = len(movie_genres_list[0])
    else:
        feature_dict['num_genres'] = 0

    feature_dict['is_drama'] = int('Drama' in movie_genres_list[0]) if movie_genres_list.size > 0 else 0

    movie_popularity = ratings_df.groupby('movieId')['rating'].count().reset_index(name='movie_rating_count')
    popularity_threshold = movie_popularity['movie_rating_count'].median()
    
    movie_rating_count = ratings_df[ratings_df['movieId'] == movie_id].shape[0]
    feature_dict['is_popular'] = int(movie_rating_count >= popularity_threshold)

    movies_df['genres'] = movies_df['genres'].apply(lambda x: x.split('|') if isinstance(x, str) else x)
    movie_genres = movies_df.loc[movies_df['movieId'] == movie_id, 'genres'].explode().dropna()

    if not movie_genres.empty:
        feature_dict['weighted_avg_rating'] = movie_genres.map(average_rating_per_genre).mean()
    else:
        feature_dict['weighted_avg_rating'] = 0  

    feature_dict['timestamp'] = int(feature_dict['timestamp'])
    
    features_df = pd.DataFrame([feature_dict])
    
    features_df = features_df.drop(['top_similar_users', 'top_similar_movies', '(no genres listed)', 'Action', 'Adventure',
       'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama',
       'Fantasy', 'Film-Noir', 'Horror', 'IMAX', 'Musical', 'Mystery',
       'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western'], axis=1)
    return features_df

user_id = 383  
movie_id = 1076 
features_for_prediction = feature_extractor(user_id, movie_id, pd.read_csv("movielens_dataset/ratings.csv"), pd.read_csv("movielens_dataset/movies.csv"), pd.read_csv("movielens_dataset/tags.csv"), user_similarity_df, item_similarity_df)

print(features_for_prediction)
# Out:
#    avg_rating_of_similar_movies  avg_rating_similar_users  user_avg_rating  \
# 0                             0                  0.017555         3.794118
#
#    user_rating_count  movie_avg_rating  movie_rating_count   timestamp  hour  \
# 0                 34          3.501557                   0  1714298099     9
#
#    day_of_week  day  ...  year  interaction_movie_user  tag_count  \
# 0            6   28  ...  2024              119.052937          1
#
#    user_rating_count_squared  movieId  userId  num_genres  is_drama  \
# 0                       1156     1076     383           3         1
#
#    is_popular  weighted_avg_rating
# 0           0             3.469362
#
# [1 rows x 21 columns]

# %%
desired_column_order = ['userId', 'movieId', 'timestamp', 'weighted_avg_rating', 'num_genres',
       'user_avg_rating', 'is_drama', 'hour', 'day_of_week', 'day', 'month',
       'year', 'user_rating_count', 'movie_avg_rating', 'movie_rating_count',
       'is_popular', 'tag_count', 'avg_rating_similar_users',
       'avg_rating_of_similar_movies', 'interaction_movie_user',
       'user_rating_count_squared']

features_for_prediction = features_for_prediction[desired_column_order]
column_names = features_for_prediction.columns

# %% [markdown]
# #### Testing

# %%
loaded_model = load('best_model.joblib')
predicted_feedback = loaded_model.predict(features_for_prediction) 
print(predicted_feedback)
# Out:
# [3.5802162]

# %% [markdown]
# ## Collabrative-based Rec System

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import random
from datetime import datetime

ratings_rec = pd.read_csv("movielens_dataset/ratings.csv")
movies_rec = pd.read_csv("movielens_dataset/movies.csv")
tags_rec = pd.read_csv("movielens_dataset/tags.csv")

class StoreTagRecommendFunctions:
    def __init__(self, ratings_df, movies_df, tags_df):
        self.ratings = ratings_df
        self.movies = movies_df
        self.tags = tags_df

        self.ratings_counts = self.ratings.groupby('userId').size()
        self.active_users = self.ratings_counts[self.ratings_counts >= 20].index
        self.ratings = self.ratings[self.ratings['userId'].isin(self.active_users)]
        self.movies = self.movies[self.movies['genres'] != '(no genres listed)']

        self.user_movie_matrix = self.ratings.pivot_table(index='userId', columns='movieId', values='rating').fillna(0)
        self.user_similarities = cosine_similarity(self.user_movie_matrix)

        self.movie_tags = pd.merge(self.tags, self.movies, on='movieId')

        self.mood_genre_mapping = {
            "Joy": ['Adventure', 'Children', 'Fantasy', 'Comedy', 'Romance', 'Documentary', 'Musical', 'Animation'],
            "Sadness": ['Drama', 'Thriller', 'Mystery', 'War', 'Action', 'Crime', 'Western', 'Film-Noir'],
            "Anger": ['Action', 'Crime', 'Western', 'Film-Noir'],
            "Fear": ['Horror', 'Sci-Fi'],
            "Disgust": ['Action', 'Crime', 'Western', 'Film-Noir']
        }

        self.previously_recommended_ids = []

    # Calculate softmax values for each score in the vector x using temperature.
    def softmax(self, x, temperature):
        exp_x = np.exp(x / temperature)
        return exp_x / np.sum(exp_x)

    # Build user profile based on movies they have rated highly.
    def build_user_profile(self, user_id):
        user_id = int(user_id)
        high_rated = self.ratings[(self.ratings['userId'] == user_id) & (self.ratings['rating'] >= 3.8)]
        high_rated = high_rated.rename(columns={'movieId_id': 'movieId'})
        high_rated_movies = high_rated.merge(self.movie_tags, on='movieId')

        if high_rated_movies.empty:
            return None

        user_profile_tags = ' '.join(high_rated_movies['tag'].tolist())
        return self.tfidf_vectorizer.transform([user_profile_tags])

    # Recomend popular movies to users
    def recommend_popular_or_trending(self, mood):
        
        aggregated_ratings = self.ratings.groupby('movieId_id').agg(
            average_rating=('rating', 'mean'),
            rating_count=('rating', 'count')
        ).reset_index()

        aggregated_ratings = aggregated_ratings.rename(columns={'movieId_id': 'movieId'})

        movies_with_ratings = pd.merge(self.movies, aggregated_ratings, on='movieId', how='left')

        mood_genres = self.mood_genre_mapping[mood]
        mood_filtered_movies = movies_with_ratings[movies_with_ratings['genres'].apply(lambda x: any(genre in x for genre in mood_genres))]

        if mood_filtered_movies.empty:
            return "No movies available for this mood."

        mood_filtered_movies = mood_filtered_movies.sort_values(by=['average_rating', 'rating_count'], ascending=[False, False])

        return mood_filtered_movies.iloc[0]['title']

    # Create TF-IDF matrix for all movie tags
    def prepare_tfidf_matrix(self):
        self.movie_tags['all_tags'] = self.movie_tags.groupby('movieId')['tag'].transform(lambda x: ' '.join(x.unique()))
        self.tfidf_vectorizer = TfidfVectorizer()
        self.tfidf_matrix = self.tfidf_vectorizer.fit_transform(self.movie_tags['all_tags'])

    # Calculate the mood relevance through genre score
    def calculate_genre_score(self, genres, mood):
        genre_list = genres.split('|')
        mood_genres = self.mood_genre_mapping[mood]
        score = sum(genre in mood_genres for genre in genre_list) / len(mood_genres)
        return score

    def content_based_recommendations(self, mood, user_id, temperature=1.2):
        if not hasattr(self, 'tfidf_matrix'):
            self.prepare_tfidf_matrix()

        user_profile = self.build_user_profile(user_id)
        if user_profile is None:
            return self.recommend_popular_or_trending(mood)

        mood_genres = self.mood_genre_mapping[mood]
        self.movies = self.movies.reset_index(drop=True)

        for index, row in self.movies.iterrows():
            self.movies.loc[index, 'genre_score'] = self.calculate_genre_score(row['genres'], mood)

        mood_filtered_movies = self.movies[self.movies['genre_score'] > 0]
        mood_filtered_movies = mood_filtered_movies.sort_values(by='genre_score', ascending=False)

        mood_filtered_movie_ids = mood_filtered_movies['movieId'].tolist()
        filtered_indices = [i for i, row in self.movie_tags.iterrows() if row['movieId'] in mood_filtered_movie_ids]
        filtered_tfidf_matrix = self.tfidf_matrix[filtered_indices]

        similarities = cosine_similarity(user_profile, filtered_tfidf_matrix).flatten()
        probabilities = self.softmax(similarities, temperature)

        chosen_index = np.random.choice(range(len(probabilities)), p=probabilities)
        chosen_movie_id = mood_filtered_movies.iloc[chosen_index]['movieId']
        recommended_movie_title = mood_filtered_movies[mood_filtered_movies['movieId'] == chosen_movie_id]['title'].iloc[0]

        return recommended_movie_title


    def collaborative_filtering_recommendations(self, user_id, mood):
        genres = self.mood_genre_mapping[mood]
        
        mood_filtered_movies = self.movies[self.movies['genre_score'] > 0]
        mood_filtered_movie_ids = mood_filtered_movies['movieId'].unique()
        
        valid_movie_ids = [movie_id for movie_id in mood_filtered_movie_ids if movie_id in self.user_movie_matrix.columns]
        
        mood_filtered_matrix = self.user_movie_matrix[valid_movie_ids].copy()
        mood_filtered_matrix.fillna(0, inplace=True)
        
        user_similarities = cosine_similarity(mood_filtered_matrix)
        user_index = list(self.user_movie_matrix.index).index(int(user_id))
        user_sim_scores = list(enumerate(user_similarities[user_index]))
        user_sim_scores = sorted(user_sim_scores, key=lambda x: x[1], reverse=True)
        similar_users_indices = [i[0] for i in user_sim_scores[1:6]] 
        
        similar_users_ratings = mood_filtered_matrix.iloc[similar_users_indices]
        user_ratings = mood_filtered_matrix.iloc[user_index]
        
        recommended = similar_users_ratings.mean(axis=0) - user_ratings
        recommended = recommended[recommended > 0].sort_values(ascending=False)
        
        recommended = recommended.index.intersection(mood_filtered_movies['movieId'])
        
        top_recommended_movie_id = recommended[0] if not recommended.empty else None
        if top_recommended_movie_id:
            top_recommended_movie = self.movies[self.movies['movieId'] == top_recommended_movie_id]['title'].iloc[0]
            return top_recommended_movie, top_recommended_movie_id
        else:
            return None

    # Updates the movie rating based on user's interaction
    def update_user_preference(self, movie_id, action, user_id):
        user_id = int(user_id)
        movie_id = int(movie_id)
    
        new_rating = 3.5 if action == "Like" else 2 if action == "Dislike" else 4.5
    
        if action == "Like":
            self.user_movie_matrix.loc[user_id, movie_id] = 3.5
        elif action == "Dislike":
            self.user_movie_matrix.loc[user_id, movie_id] = 2
        else:
            self.user_movie_matrix.loc[user_id, movie_id] = 4.5
    
        try:
            mask = (self.ratings['userId'] == user_id) & (self.ratings['movieId'] == movie_id)
            if mask.any():
                self.ratings.loc[mask, 'rating'] = new_rating
                self.ratings.loc[mask, 'timestamp'] = datetime.now()
                print("Rating updated.")
            else:
                new_entry = pd.DataFrame({
                    'userId': [user_id],
                    'movieId': [movie_id],
                    'rating': [new_rating],
                    'timestamp': [datetime.now()]
                })
                self.ratings = pd.concat([self.ratings, new_entry], ignore_index=True)
                print("New rating added.")
        except Exception as e:
            print(f"An error occurred: {e}")


    # Process the user's action on a recommended movie
    def process_user_action(self, movie_title, action, user_id, mood, type):
        response = {
            'message': '',
            'next_recommendation_id': None,
            'next_recommendation': None,
            'action': action,
        }

        try:
            movie = self.movies[self.movies['title'] == movie_title].iloc[0]
            movie_id = movie['movieId']
        except IndexError:
            response['message'] = "Movie not found."
            return response

        self.update_user_preference(movie_id, action, user_id)

        if action in ["Like", "Dislike"]:
            try:
                if type == "score":
                    next_recommendation, next_recommendation_id = self.collaborative_filtering_recommendations(user_id, mood)
                elif type == "tag":
                    next_recommendation, next_recommendation_id = self.mood_filtered_tag_recommendations(user_id, mood)
                if next_recommendation:
                    response['next_recommendation'] = next_recommendation
                    response['next_recommendation_id'] = next_recommendation_id
                else:
                    response['message'] += " We're out of recommendations for now."
            except Exception as e:
                print(e)
                response['message'] += f" Error generating next recommendation: {e}"

        return response

# %% [markdown]
# ## Content-based Rec System

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import random
from datetime import datetime


ratings_rec = pd.read_csv("movielens_dataset/ratings.csv")
movies_rec = pd.read_csv("movielens_dataset/movies.csv")
tags_rec = pd.read_csv("movielens_dataset/tags.csv")

class TagRecommendFunctions:
    def __init__(self, ratings_df, movies_df, tags_df):
        self.ratings = ratings_df
        self.movies = movies_df
        self.tags = tags_df

        self.ratings_counts = self.ratings.groupby('userId').size()
        self.active_users = self.ratings_counts[self.ratings_counts >= 20].index
        self.ratings = self.ratings[self.ratings['userId'].isin(self.active_users)]
        self.movies = self.movies[self.movies['genres'] != '(no genres listed)']

        self.user_movie_matrix = self.ratings.pivot_table(index='userId', columns='movieId', values='rating').fillna(0)
        self.user_similarities = cosine_similarity(self.user_movie_matrix)

        self.movie_tags = pd.merge(self.tags, self.movies, on='movieId')

        self.mood_genre_mapping = {
            "Joy": ['Adventure', 'Children', 'Fantasy', 'Comedy', 'Romance', 'Documentary', 'Musical', 'Animation'],
            "Sadness": ['Drama', 'Thriller', 'Mystery', 'War', 'Action', 'Crime', 'Western', 'Film-Noir'],
            "Anger": ['Action', 'Crime', 'Western', 'Film-Noir'],
            "Fear": ['Horror', 'Sci-Fi'],
            "Disgust": ['Action', 'Crime', 'Western', 'Film-Noir']
        }

        self.previously_recommended_ids = []
        
    # Calculate softmax values for each score in the vector x using temperature.
    def softmax(self, x, temperature):
        """Compute softmax values for each score in the vector x using temperature."""
        exp_x = np.exp(x / temperature)
        return exp_x / np.sum(exp_x)

    # Build user profile based on movies they have rated highly.
    def build_user_profile(self, user_id):
        user_id = int(user_id)
        high_rated = self.ratings[(self.ratings['userId'] == user_id) & (self.ratings['rating'] >= 3.8)]
        high_rated = high_rated.rename(columns={'movieId_id': 'movieId'})
        high_rated_movies = high_rated.merge(self.movie_tags, on='movieId')

        if high_rated_movies.empty:
            return None

        user_profile_tags = ' '.join(high_rated_movies['tag'].tolist())
        return self.tfidf_vectorizer.transform([user_profile_tags])

    # Recomend popular movies to users
    def recommend_popular_or_trending(self, mood):
        aggregated_ratings = self.ratings.groupby('movieId_id').agg(
            average_rating=('rating', 'mean'),
            rating_count=('rating', 'count')
        ).reset_index()

        aggregated_ratings = aggregated_ratings.rename(columns={'movieId_id': 'movieId'})

        movies_with_ratings = pd.merge(self.movies, aggregated_ratings, on='movieId', how='left')

        mood_genres = self.mood_genre_mapping[mood]
        mood_filtered_movies = movies_with_ratings[movies_with_ratings['genres'].apply(lambda x: any(genre in x for genre in mood_genres))]

        if mood_filtered_movies.empty:
            return "No movies available for this mood."

        mood_filtered_movies = mood_filtered_movies.sort_values(by=['average_rating', 'rating_count'], ascending=[False, False])

        return mood_filtered_movies.iloc[0]['title']

    # Create TF-IDF matrix for all movie tags
    def prepare_tfidf_matrix(self):
        self.movie_tags['all_tags'] = self.movie_tags.groupby('movieId')['tag'].transform(lambda x: ' '.join(x.unique()))
        self.tfidf_vectorizer = TfidfVectorizer()
        self.tfidf_matrix = self.tfidf_vectorizer.fit_transform(self.movie_tags['all_tags'])

    # Calculate the mood relevance through genre score
    def calculate_genre_score(self, genres, mood):
        genre_list = genres.split('|')
        mood_genres = self.mood_genre_mapping[mood]
        score = sum(genre in mood_genres for genre in genre_list) / len(mood_genres)
        return score

    def content_based_recommendations(self, mood, user_id, temperature=1.2):
        if not hasattr(self, 'tfidf_matrix'):
            self.prepare_tfidf_matrix()

        user_profile = self.build_user_profile(user_id)
        if user_profile is None:
            return self.recommend_popular_or_trending(mood)

        mood_genres = self.mood_genre_mapping[mood]
        self.movies = self.movies.reset_index(drop=True)

        for index, row in self.movies.iterrows():
            self.movies.loc[index, 'genre_score'] = self.calculate_genre_score(row['genres'], mood)

        mood_filtered_movies = self.movies[self.movies['genre_score'] > 0]
        mood_filtered_movies = mood_filtered_movies.sort_values(by='genre_score', ascending=False)

        mood_filtered_movie_ids = mood_filtered_movies['movieId'].tolist()
        filtered_indices = [i for i, row in self.movie_tags.iterrows() if row['movieId'] in mood_filtered_movie_ids]
        filtered_tfidf_matrix = self.tfidf_matrix[filtered_indices]

        similarities = cosine_similarity(user_profile, filtered_tfidf_matrix).flatten()
        probabilities = self.softmax(similarities, temperature)

        chosen_index = np.random.choice(range(len(probabilities)), p=probabilities)
        chosen_movie_id = mood_filtered_movies.iloc[chosen_index]['movieId']
        recommended_movie_title = mood_filtered_movies[mood_filtered_movies['movieId'] == chosen_movie_id]['title'].iloc[0]

        return recommended_movie_title

    def mood_filtered_tag_recommendations(self, user_id, mood):
        mood_genres = self.mood_genre_mapping[mood]
        mood_filtered_movies = self.movies[self.movies['genre_score'] > 0]
        mood_filtered_movies = mood_filtered_movies.sort_values(by='genre_score', ascending=False)


        watched_movie_ids_series = self.ratings[self.ratings['userId'] == int(user_id)]['movieId']
        watched_movie_ids = set(watched_movie_ids_series.unique())
        
        if watched_movie_ids_series.empty:
            return "No watched movies found for the user."

        all_excluded_movie_ids = watched_movie_ids.union(self.previously_recommended_ids)
        candidate_movies = mood_filtered_movies[~mood_filtered_movies['movieId'].isin(all_excluded_movie_ids)]
        
        if candidate_movies.empty:
            return "No suitable recommendations based on your mood and preferences at the moment."

        candidate_indices = [self.movie_tags[self.movie_tags['movieId'] == movie_id].index[0] for movie_id in candidate_movies['movieId'] if not self.movie_tags[self.movie_tags['movieId'] == movie_id].index.empty]
        valid_tfidf_matrix = self.tfidf_matrix[candidate_indices]
        
        tag_similarities = cosine_similarity(valid_tfidf_matrix, self.tfidf_matrix)
        mean_similarities = tag_similarities.mean(axis=1)
        max_sim_index = np.argmax(mean_similarities)
        
        recommended_movie_id = candidate_movies.iloc[max_sim_index]['movieId']
        recommended_movie_title = candidate_movies[candidate_movies['movieId'] == recommended_movie_id]['title'].iloc[0]

        self.previously_recommended_ids.append(recommended_movie_id)
        return recommended_movie_title, recommended_movie_id

        
        return recommended_movie_title

    # Updates the movie rating based on user's interaction
    def update_user_preference(self, movie_id, action, user_id):
        user_id = int(user_id)
        movie_id = int(movie_id)
    
        new_rating = 3.5 if action == "Like" else 2 if action == "Dislike" else 4.5
    
        if action == "Like":
            self.user_movie_matrix.loc[user_id, movie_id] = 3.5
        elif action == "Dislike":
            self.user_movie_matrix.loc[user_id, movie_id] = 2
        else:
            self.user_movie_matrix.loc[user_id, movie_id] = 4.5
    
        try:
            mask = (self.ratings['userId'] == user_id) & (self.ratings['movieId'] == movie_id)
            if mask.any():
                self.ratings.loc[mask, 'rating'] = new_rating
                self.ratings.loc[mask, 'timestamp'] = datetime.now()
                print("Rating updated.")
            else:
                new_entry = pd.DataFrame({
                    'userId': [user_id],
                    'movieId': [movie_id],
                    'rating': [new_rating],
                    'timestamp': [datetime.now()]
                })
                self.ratings = pd.concat([self.ratings, new_entry], ignore_index=True)
                print("New rating added.")
        except Exception as e:
            print(f"An error occurred: {e}")

    # Process the user's action on a recommended movie
    def process_user_action(self, movie_title, action, user_id, mood, type):
        """
        Process the user's action on a recommended movie and provide the next steps.
        """
        response = {
            'message': '',
            'next_recommendation_id': None,
            'next_recommendation': None,
            'action': action,
        }

        try:
            movie = self.movies[self.movies['title'] == movie_title].iloc[0]
            movie_id = movie['movieId']
        except IndexError:
            response['message'] = "Movie not found."
            return response

        self.update_user_preference(movie_id, action, user_id)

        if action in ["Like", "Dislike"]:
            try:
                if type == "score":
                    next_recommendation, next_recommendation_id = self.collaborative_filtering_recommendations(user_id, mood)
                elif type == "tag":
                    next_recommendation, next_recommendation_id = self.mood_filtered_tag_recommendations(user_id, mood)
                if next_recommendation:
                    response['next_recommendation'] = next_recommendation
                    response['next_recommendation_id'] = next_recommendation_id
                else:
                    response['message'] += " We're out of recommendations for now."
            except Exception as e:
                print(e)
                response['message'] += f" Error generating next recommendation: {e}"

        return response

# %% [markdown]
# # Popular Rec System (Baseline)

# %%
import pandas as pd
import numpy as np

class PopularMoviesRecommendationSystem:
    def __init__(self):
        self.movies_df = pd.read_csv("movielens_dataset/movies.csv")
        self.ratings_df = pd.read_csv("movielens_dataset/ratings.csv")
        
        self.sorted_movies_df = self.compute_and_sort_popularity()
        self.top_25_percent_movies = self.get_top_25_percent()
        self.recommended_movie_ids = set()

    def compute_and_sort_popularity(self):
        movie_ratings = pd.merge(self.ratings_df, self.movies_df, on='movieId')
        
        popularity = movie_ratings.groupby('movieId').agg(
            average_rating=pd.NamedAgg(column='rating', aggfunc='mean'),
            rating_count=pd.NamedAgg(column='rating', aggfunc='size')
        ).reset_index()
        
        movies_popularity = pd.merge(self.movies_df, popularity, on='movieId', how='left')
        
        return movies_popularity.sort_values(by=['rating_count', 'average_rating'], ascending=False)

    # Determine the number of movies to consider as the top 25%
    def get_top_25_percent(self):
        top_25_index = int(len(self.sorted_movies_df) * 0.25)
        return self.sorted_movies_df.head(top_25_index)

    def recommend(self):
        available_movies = self.top_25_percent_movies[~self.top_25_percent_movies['movieId'].isin(self.recommended_movie_ids)]
        
        if not available_movies.empty:
            random_index = np.random.randint(0, len(available_movies))
            recommended_movie = available_movies.iloc[random_index]
            
            self.recommended_movie_ids.add(recommended_movie['movieId'])
            
            return recommended_movie['title']
        else:
            return "No more movies available for recommendation."

# %% [markdown]
# # Simulator

# %%
import random
from sklearn.metrics import classification_report
from joblib import load

def find_movie_id_by_exact_name(movie_name):
    movies_df = pd.read_csv("movielens_dataset/movies.csv")
    matched_movies = movies_df[movies_df['title'] == movie_name]
    if not matched_movies.empty:
        return matched_movies['movieId'].tolist()
    else:
        return "Movie not found."

# Main funtion to run the simulation. Type helps to understand which recomendation system to run
def simulate_user_experience(user_profile, recommendation_system, model, type):
    recommendations = []
    feedbacks = []
    initial_mood = user_profile['mood']
    print(f"Starting simulation with mood: {initial_mood}")

    if type=="popular":
        current_recommendation = recommendation_system.recommend()
    else:
        current_recommendation = recommendation_system.content_based_recommendations(initial_mood, user_id)
        
    while True:
        m_id = find_movie_id_by_exact_name(current_recommendation)
        movie_id = int("".join(map(str, m_id)))
        print(movie_id)
        features_for_prediction = feature_extractor(user_id, movie_id, pd.read_csv("movielens_dataset/ratings.csv"), pd.read_csv("movielens_dataset/movies.csv"), pd.read_csv("movielens_dataset/tags.csv"), user_similarity_df, item_similarity_df)
        
        desired_column_order = ['userId', 'movieId', 'timestamp', 'weighted_avg_rating', 'num_genres',
       'user_avg_rating', 'is_drama', 'hour', 'day_of_week', 'day', 'month',
       'year', 'user_rating_count', 'movie_avg_rating', 'movie_rating_count',
       'is_popular', 'tag_count', 'avg_rating_similar_users',
       'avg_rating_of_similar_movies', 'interaction_movie_user',
       'user_rating_count_squared']
        
        features_for_prediction = features_for_prediction[desired_column_order]
        
        predicted_feedback = model.predict(features_for_prediction) 
        print(predicted_feedback)

        if predicted_feedback <= 2.8:
            feedback_cat = "Dislike"
        elif predicted_feedback <= 3.8:
            feedback_cat = "Like"
        else:
            feedback_cat = "Perfect"
            
        recommendations.append(current_recommendation)
        feedbacks.append(feedback_cat)
        
        print(f"Simulated feedback for '{current_recommendation}': {feedback_cat}")
        
        if feedback_cat == "Perfect":
            print(f"User found the perfect movie: {current_recommendation}")
            break
        else:
            if type == "score":
                res = recommendation_system.process_user_action(current_recommendation, feedback_cat, user_id, initial_mood, "score")
                current_recommendation = res['next_recommendation']
            elif type == "tag":
                res = recommendation_system.process_user_action(current_recommendation, feedback_cat, user_id, initial_mood, "tag")
                current_recommendation = res['next_recommendation']
            elif type == "popular":
                current_recommendation = recommendation_system.recommend()
            if not current_recommendation:
                print("No more recommendations available.")
                break

    print("\nSimulation Summary:")
    print(f"Total recommendations made: {len(recommendations)}")
    if "perfect" in feedbacks:
        print(f"Recommendations until perfect: {feedbacks.index('perfect') + 1}")
    else:
        print("No perfect recommendation found during the simulation.")

    return recommendations, feedbacks, initial_mood

def run_simulation_across_users(user_profiles, model):
    tag_score_simulation_results = {}
    tag_simulation_results = {}
    popular_simulation_results = {}

    for user_id, user_profile in user_profiles.items():
        recommendation_system = StoreTagRecommendFunctions(ratings_rec, movies_rec, tags_rec)
        print(f"\nSimulating experience for User ID: {user_id}")

        recommendations, feedbacks, mood = simulate_user_experience(user_profile, recommendation_system, model, "score")

        print(recommendations)
        print(feedbacks)
        tag_score_simulation_results[user_id] = {
            'userId' : user_id,
            'mood' : mood,
            'recommendations': recommendations,
            'feedbacks': feedbacks,
            'number of recs': len(recommendations),
        }

    for user_id, user_profile in user_profiles.items():
        recommendation_system = TagRecommendFunctions(ratings_rec, movies_rec, tags_rec)
        print(f"\nSimulating experience for User ID: {user_id}")

        recommendations, feedbacks, mood = simulate_user_experience(user_profile, recommendation_system, model, "tag")

        print(recommendations)
        print(feedbacks)
        tag_simulation_results[user_id] = {
            'userId' : user_id,
            'mood' : mood,
            'recommendations': recommendations,
            'feedbacks': feedbacks,
            'number of recs': len(recommendations),
        }

    for user_id, user_profile in user_profiles.items():
        recommendation_system = PopularMoviesRecommendationSystem()
        print(f"\nSimulating experience for User ID: {user_id}")

        recommendations, feedbacks, mood = simulate_user_experience(user_profile, recommendation_system, model, "popular")

        print(recommendations)
        print(feedbacks)
        popular_simulation_results[user_id] = {
            'userId' : user_id,
            'mood' : mood,
            'recommendations': recommendations,
            'feedbacks': feedbacks,
            'number of recs': len(recommendations),
        }

    score_tag_results_df = pd.DataFrame.from_dict(tag_score_simulation_results, orient='index')
    score_tag_results_df.to_csv("simulation_results_score_tag.csv")
    print("All simulations completed. Results saved.")

    tag_results_df = pd.DataFrame.from_dict(tag_simulation_results, orient='index')
    tag_results_df.to_csv("simulation_results_tag.csv")
    print("All simulations completed. Results saved.")

    # Save the results to a file or analyze 
    popular_results_df = pd.DataFrame.from_dict(popular_simulation_results, orient='index')
    popular_results_df.to_csv("simulation_results_popular.csv")
    print("All simulations completed. Results saved.")

# Feedback Predictor
loaded_model = load('best_model.joblib')
run_simulation_across_users(user_profiles, loaded_model)
# Out:
# Simulating experience for User ID: 1
# Starting simulation with mood: Disgust
# 43912
# [1.7139667]
# Simulated feedback for 'Freedomland (2006)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Freedomland (2006)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 2
# Starting simulation with mood: Anger
# 102278
# [1.2750622]
# Simulated feedback for 'Pawn (2013)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Pawn (2013)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 3
# Starting simulation with mood: Anger
# 6874
# [4.2065682]
# Simulated feedback for 'Kill Bill: Vol. 1 (2003)': Perfect
# User found the perfect movie: Kill Bill: Vol. 1 (2003)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Kill Bill: Vol. 1 (2003)']
# ['Perfect']
#
# Simulating experience for User ID: 4
# Starting simulation with mood: Sadness
# 5843
# [2.516829]
# Simulated feedback for 'Toy Soldiers (1991)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Toy Soldiers (1991)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 5
# Starting simulation with mood: Disgust
# 79895
# [2.6731172]
# Simulated feedback for 'Extraordinary Adventures of Adèle Blanc-Sec, The (2010)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Extraordinary Adventures of Adèle Blanc-Sec, The (2010)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 6
# Starting simulation with mood: Sadness
# 138186
# [-0.07960171]
# Simulated feedback for 'Sorrow (2015)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Sorrow (2015)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 7
# Starting simulation with mood: Joy
# 3393
# [-0.46890488]
# Simulated feedback for 'Date with an Angel (1987)': Dislike
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Date with an Angel (1987)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 8
# Starting simulation with mood: Joy
# 77866
# [3.2888975]
# Simulated feedback for 'Robin Hood (2010)': Like
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Robin Hood (2010)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 9
# Starting simulation with mood: Anger
# 996
# [2.3388932]
# Simulated feedback for 'Last Man Standing (1996)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 1262
# [4.495596]
# Simulated feedback for 'Great Escape, The (1963)': Perfect
# User found the perfect movie: Great Escape, The (1963)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Last Man Standing (1996)', 'Sneakers (1992)', 'Great Escape, The (1963)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 10
# Starting simulation with mood: Sadness
# 91128
# [3.7611885]
# Simulated feedback for 'Rum Diary, The (2011)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Rum Diary, The (2011)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 11
# Starting simulation with mood: Sadness
# 8507
# [3.0203831]
# Simulated feedback for 'Freaks (1932)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Freaks (1932)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 12
# Starting simulation with mood: Disgust
# 38294
# [2.7945657]
# Simulated feedback for 'Beowulf & Grendel (2005)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Beowulf & Grendel (2005)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 13
# Starting simulation with mood: Anger
# 2126
# [2.842358]
# Simulated feedback for 'Snake Eyes (1998)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Snake Eyes (1998)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 14
# Starting simulation with mood: Sadness
# 161582
# [3.1990874]
# Simulated feedback for 'Hell or High Water (2016)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Hell or High Water (2016)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 15
# Starting simulation with mood: Fear
# 172875
# [4.737032]
# Simulated feedback for 'A Detective Story (2003)': Perfect
# User found the perfect movie: A Detective Story (2003)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['A Detective Story (2003)']
# ['Perfect']
#
# Simulating experience for User ID: 16
# Starting simulation with mood: Sadness
# 2722
# [3.0673962]
# Simulated feedback for 'Deep Blue Sea (1999)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Deep Blue Sea (1999)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 17
# Starting simulation with mood: Joy
# 141830
# [2.812119]
# Simulated feedback for 'Unbelievable Adventures of Italians in Russia (1974)': Like
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Unbelievable Adventures of Italians in Russia (1974)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 18
# Starting simulation with mood: Anger
# 2307
# [2.1564336]
# Simulated feedback for 'One Tough Cop (1998)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['One Tough Cop (1998)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 19
# Starting simulation with mood: Joy
# 3345
# [2.3997636]
# Simulated feedback for 'Charlie, the Lonesome Cougar (1967)': Dislike
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Charlie, the Lonesome Cougar (1967)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 20
# Starting simulation with mood: Anger
# 3275
# [4.2262897]
# Simulated feedback for 'Boondock Saints, The (2000)': Perfect
# User found the perfect movie: Boondock Saints, The (2000)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Boondock Saints, The (2000)']
# ['Perfect']
#
# Simulating experience for User ID: 21
# Starting simulation with mood: Sadness
# 7762
# [3.833455]
# Simulated feedback for 'Tinker, Tailor, Soldier, Spy (1979)': Perfect
# User found the perfect movie: Tinker, Tailor, Soldier, Spy (1979)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Tinker, Tailor, Soldier, Spy (1979)']
# ['Perfect']
#
# Simulating experience for User ID: 22
# Starting simulation with mood: Disgust
# 74580
# [1.521153]
# Simulated feedback for 'Spy Next Door, The (2010)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Spy Next Door, The (2010)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 23
# Starting simulation with mood: Fear
# 84187
# [3.5897844]
# Simulated feedback for 'Evangelion: 2.0 You Can (Not) Advance (Evangerion shin gekijôban: Ha) (2009)': Like
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Evangelion: 2.0 You Can (Not) Advance (Evangerion shin gekijôban: Ha) (2009)', 'Matrix, The (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 24
# Starting simulation with mood: Anger
# 161918
# [0.5091997]
# Simulated feedback for 'Sharknado 4: The 4th Awakens (2016)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Sharknado 4: The 4th Awakens (2016)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 25
# Starting simulation with mood: Disgust
# 69524
# [4.3238587]
# Simulated feedback for 'Raiders of the Lost Ark: The Adaptation (1989)': Perfect
# User found the perfect movie: Raiders of the Lost Ark: The Adaptation (1989)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Raiders of the Lost Ark: The Adaptation (1989)']
# ['Perfect']
#
# Simulating experience for User ID: 26
# Starting simulation with mood: Anger
# 110826
# [0.424537]
# Simulated feedback for 'Brick Mansions (2014)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Brick Mansions (2014)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 27
# Starting simulation with mood: Anger
# 55391
# [4.719752]
# Simulated feedback for '10th & Wolf (2006)': Perfect
# User found the perfect movie: 10th & Wolf (2006)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['10th & Wolf (2006)']
# ['Perfect']
#
# Simulating experience for User ID: 28
# Starting simulation with mood: Sadness
# 83374
# [3.2369823]
# Simulated feedback for 'Warrior's Way, The (2010)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ["Warrior's Way, The (2010)", 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 29
# Starting simulation with mood: Joy
# 8336
# [3.4545758]
# Simulated feedback for 'Major and the Minor, The (1942)': Like
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Major and the Minor, The (1942)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 30
# Starting simulation with mood: Joy
# 2687
# [3.6057794]
# Simulated feedback for 'Tarzan (1999)': Like
# New rating added.
# 2858
# [4.346073]
# Simulated feedback for 'American Beauty (1999)': Perfect
# User found the perfect movie: American Beauty (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Tarzan (1999)', 'American Beauty (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 31
# Starting simulation with mood: Anger
# 3717
# [3.222616]
# Simulated feedback for 'Gone in 60 Seconds (2000)': Like
# New rating added.
# 1198
# [3.88647]
# Simulated feedback for 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)': Perfect
# User found the perfect movie: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Gone in 60 Seconds (2000)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 32
# Starting simulation with mood: Joy
# 4777
# [2.6289213]
# Simulated feedback for 'American Astronaut, The (2001)': Dislike
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['American Astronaut, The (2001)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 33
# Starting simulation with mood: Sadness
# 45720
# [3.8906598]
# Simulated feedback for 'Devil Wears Prada, The (2006)': Perfect
# User found the perfect movie: Devil Wears Prada, The (2006)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Devil Wears Prada, The (2006)']
# ['Perfect']
#
# Simulating experience for User ID: 34
# Starting simulation with mood: Sadness
# 91660
# [2.358143]
# Simulated feedback for 'Darkest Hour, The (2011)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Darkest Hour, The (2011)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 35
# Starting simulation with mood: Joy
# 455
# [2.2921276]
# Simulated feedback for 'Free Willy (1993)': Dislike
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Free Willy (1993)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 36
# Starting simulation with mood: Sadness
# 69654
# [3.2681642]
# Simulated feedback for 'Prison Break: The Final Break (2009)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Prison Break: The Final Break (2009)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 37
# Starting simulation with mood: Disgust
# 100579
# [3.9881024]
# Simulated feedback for 'Universal Soldier: Day of Reckoning (2012)': Perfect
# User found the perfect movie: Universal Soldier: Day of Reckoning (2012)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Universal Soldier: Day of Reckoning (2012)']
# ['Perfect']
#
# Simulating experience for User ID: 38
# Starting simulation with mood: Disgust
# 145
# [2.9883165]
# Simulated feedback for 'Bad Boys (1995)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 858
# [4.4779067]
# Simulated feedback for 'Godfather, The (1972)': Perfect
# User found the perfect movie: Godfather, The (1972)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Bad Boys (1995)', 'Sneakers (1992)', 'Godfather, The (1972)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 39
# Starting simulation with mood: Anger
# 86628
# [4.1362777]
# Simulated feedback for 'Kill the Irishman (2011)': Perfect
# User found the perfect movie: Kill the Irishman (2011)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Kill the Irishman (2011)']
# ['Perfect']
#
# Simulating experience for User ID: 40
# Starting simulation with mood: Sadness
# 2905
# [4.503416]
# Simulated feedback for 'Sanjuro (Tsubaki Sanjûrô) (1962)': Perfect
# User found the perfect movie: Sanjuro (Tsubaki Sanjûrô) (1962)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Sanjuro (Tsubaki Sanjûrô) (1962)']
# ['Perfect']
#
# Simulating experience for User ID: 41
# Starting simulation with mood: Anger
# 162828
# [2.0845094]
# Simulated feedback for 'Imperium (2016)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Imperium (2016)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 42
# Starting simulation with mood: Anger
# 179819
# [2.9665668]
# Simulated feedback for 'Star Wars: The Last Jedi (2017)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Star Wars: The Last Jedi (2017)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 43
# Starting simulation with mood: Anger
# 51939
# [2.9143116]
# Simulated feedback for 'TMNT (Teenage Mutant Ninja Turtles) (2007)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['TMNT (Teenage Mutant Ninja Turtles) (2007)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 44
# Starting simulation with mood: Sadness
# 6927
# [4.0753536]
# Simulated feedback for 'Human Stain, The (2003)': Perfect
# User found the perfect movie: Human Stain, The (2003)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Human Stain, The (2003)']
# ['Perfect']
#
# Simulating experience for User ID: 45
# Starting simulation with mood: Fear
# 54785
# [3.197105]
# Simulated feedback for 'Halloween (2007)': Like
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Halloween (2007)', 'Matrix, The (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 46
# Starting simulation with mood: Disgust
# 97
# [4.101294]
# Simulated feedback for 'Hate (Haine, La) (1995)': Perfect
# User found the perfect movie: Hate (Haine, La) (1995)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Hate (Haine, La) (1995)']
# ['Perfect']
#
# Simulating experience for User ID: 47
# Starting simulation with mood: Sadness
# 44864
# [3.2603655]
# Simulated feedback for 'Friends with Money (2006)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Friends with Money (2006)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 48
# Starting simulation with mood: Joy
# 103210
# [1.5521467]
# Simulated feedback for 'Fullmetal Alchemist: The Sacred Star of Milos (2011)': Dislike
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Fullmetal Alchemist: The Sacred Star of Milos (2011)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 49
# Starting simulation with mood: Joy
# 172229
# [2.6813333]
# Simulated feedback for 'Plain Clothes (1988)': Dislike
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Plain Clothes (1988)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 50
# Starting simulation with mood: Sadness
# 78
# [2.994318]
# Simulated feedback for 'Crossing Guard, The (1995)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Crossing Guard, The (1995)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 51
# Starting simulation with mood: Fear
# 51498
# [3.4639423]
# Simulated feedback for '2001 Maniacs (2005)': Like
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['2001 Maniacs (2005)', 'Matrix, The (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 52
# Starting simulation with mood: Fear
# 94018
# [2.344837]
# Simulated feedback for 'Battleship (2012)': Dislike
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Battleship (2012)', 'Matrix, The (1999)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 53
# Starting simulation with mood: Anger
# 3104
# [3.5364137]
# Simulated feedback for 'Midnight Run (1988)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 260
# [4.1826906]
# Simulated feedback for 'Star Wars: Episode IV - A New Hope (1977)': Perfect
# User found the perfect movie: Star Wars: Episode IV - A New Hope (1977)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Midnight Run (1988)', 'Sneakers (1992)', 'Star Wars: Episode IV - A New Hope (1977)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 54
# Starting simulation with mood: Disgust
# 7040
# [2.0405672]
# Simulated feedback for 'To Live and Die in L.A. (1985)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['To Live and Die in L.A. (1985)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 55
# Starting simulation with mood: Sadness
# 55207
# [2.468523]
# Simulated feedback for 'Cashback (2004)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Cashback (2004)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 56
# Starting simulation with mood: Anger
# 61026
# [4.029664]
# Simulated feedback for 'Red Cliff (Chi bi) (2008)': Perfect
# User found the perfect movie: Red Cliff (Chi bi) (2008)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Red Cliff (Chi bi) (2008)']
# ['Perfect']
#
# Simulating experience for User ID: 57
# Starting simulation with mood: Joy
# 378
# [2.3254445]
# Simulated feedback for 'Speechless (1994)': Dislike
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Speechless (1994)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 58
# Starting simulation with mood: Joy
# 2581
# [3.0517714]
# Simulated feedback for 'Never Been Kissed (1999)': Like
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Never Been Kissed (1999)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 59
# Starting simulation with mood: Sadness
# 5809
# [3.017935]
# Simulated feedback for 'Femme Fatale (2002)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Femme Fatale (2002)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 60
# Starting simulation with mood: Sadness
# 89343
# [2.5707111]
# Simulated feedback for 'Red State (2011)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Red State (2011)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 61
# Starting simulation with mood: Sadness
# 6280
# [1.9529634]
# Simulated feedback for 'Man Apart, A (2003)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Man Apart, A (2003)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 62
# Starting simulation with mood: Disgust
# 94780
# [2.9757137]
# Simulated feedback for 'Snow White and the Huntsman (2012)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Snow White and the Huntsman (2012)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 63
# Starting simulation with mood: Fear
# 37720
# [3.1919794]
# Simulated feedback for 'Exorcism of Emily Rose, The (2005)': Like
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Exorcism of Emily Rose, The (2005)', 'Matrix, The (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 64
# Starting simulation with mood: Disgust
# 79553
# [2.701341]
# Simulated feedback for 'Ip Man 2 (2010)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Ip Man 2 (2010)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 65
# Starting simulation with mood: Joy
# 955
# [3.9105325]
# Simulated feedback for 'Bringing Up Baby (1938)': Perfect
# User found the perfect movie: Bringing Up Baby (1938)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Bringing Up Baby (1938)']
# ['Perfect']
#
# Simulating experience for User ID: 66
# Starting simulation with mood: Sadness
# 38061
# [4.4354444]
# Simulated feedback for 'Kiss Kiss Bang Bang (2005)': Perfect
# User found the perfect movie: Kiss Kiss Bang Bang (2005)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Kiss Kiss Bang Bang (2005)']
# ['Perfect']
#
# Simulating experience for User ID: 67
# Starting simulation with mood: Fear
# 5189
# [0.6013487]
# Simulated feedback for 'Humanoids from the Deep (1980)': Dislike
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Humanoids from the Deep (1980)', 'Matrix, The (1999)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 68
# Starting simulation with mood: Disgust
# 908
# [4.2392397]
# Simulated feedback for 'North by Northwest (1959)': Perfect
# User found the perfect movie: North by Northwest (1959)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['North by Northwest (1959)']
# ['Perfect']
#
# Simulating experience for User ID: 69
# Starting simulation with mood: Sadness
# 7017
# [3.2047374]
# Simulated feedback for 'Passenger 57 (1992)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Passenger 57 (1992)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 70
# Starting simulation with mood: Fear
# 68358
# [4.1474824]
# Simulated feedback for 'Star Trek (2009)': Perfect
# User found the perfect movie: Star Trek (2009)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Star Trek (2009)']
# ['Perfect']
#
# Simulating experience for User ID: 71
# Starting simulation with mood: Sadness
# 7122
# [4.75491]
# Simulated feedback for 'King of Hearts (1966)': Perfect
# User found the perfect movie: King of Hearts (1966)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['King of Hearts (1966)']
# ['Perfect']
#
# Simulating experience for User ID: 72
# Starting simulation with mood: Anger
# 5049
# [3.4491062]
# Simulated feedback for '48 Hrs. (1982)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['48 Hrs. (1982)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 73
# Starting simulation with mood: Fear
# 187031
# [2.9358628]
# Simulated feedback for 'Jurassic World: Fallen Kingdom (2018)': Like
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Jurassic World: Fallen Kingdom (2018)', 'Matrix, The (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 74
# Starting simulation with mood: Anger
# 46335
# [2.2788696]
# Simulated feedback for 'Fast and the Furious: Tokyo Drift, The (Fast and the Furious 3, The) (2006)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Fast and the Furious: Tokyo Drift, The (Fast and the Furious 3, The) (2006)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 75
# Starting simulation with mood: Fear
# 170297
# [1.3176931]
# Simulated feedback for 'Ultimate Avengers 2 (2006)': Dislike
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Ultimate Avengers 2 (2006)', 'Matrix, The (1999)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 76
# Starting simulation with mood: Joy
# 137859
# [3.7248926]
# Simulated feedback for 'Dragon Ball Z Gaiden: The Plot to Destroy the Saiyans (1993)': Like
# New rating added.
# 1210
# [4.3962984]
# Simulated feedback for 'Star Wars: Episode VI - Return of the Jedi (1983)': Perfect
# User found the perfect movie: Star Wars: Episode VI - Return of the Jedi (1983)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Dragon Ball Z Gaiden: The Plot to Destroy the Saiyans (1993)', 'Star Wars: Episode VI - Return of the Jedi (1983)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 77
# Starting simulation with mood: Anger
# 59129
# [1.9183264]
# Simulated feedback for 'Outpost (2008)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Outpost (2008)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 78
# Starting simulation with mood: Disgust
# 117646
# [4.644342]
# Simulated feedback for 'Dragonheart 2: A New Beginning (2000)': Perfect
# User found the perfect movie: Dragonheart 2: A New Beginning (2000)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Dragonheart 2: A New Beginning (2000)']
# ['Perfect']
#
# Simulating experience for User ID: 79
# Starting simulation with mood: Fear
# 8138
# [2.4263096]
# Simulated feedback for 'Attack of the Giant Leeches (1959)': Dislike
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Attack of the Giant Leeches (1959)', 'Matrix, The (1999)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 80
# Starting simulation with mood: Disgust
# 110826
# [0.424537]
# Simulated feedback for 'Brick Mansions (2014)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Brick Mansions (2014)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 81
# Starting simulation with mood: Fear
# 2851168358
# [3.6250494]
# Simulated feedback for 'Saturn 3 (1980)': Like
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Saturn 3 (1980)', 'Matrix, The (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 82
# Starting simulation with mood: Fear
# 7001
# [3.9238987]
# Simulated feedback for 'Invasion of the Body Snatchers (1978)': Perfect
# User found the perfect movie: Invasion of the Body Snatchers (1978)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Invasion of the Body Snatchers (1978)']
# ['Perfect']
#
# Simulating experience for User ID: 83
# Starting simulation with mood: Sadness
# 1801
# [3.7529411]
# Simulated feedback for 'Man in the Iron Mask, The (1998)': Like
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Man in the Iron Mask, The (1998)', 'Stand by Me (1986)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 84
# Starting simulation with mood: Fear
# 166635
# [3.682095]
# Simulated feedback for 'Passengers (2016)': Like
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Passengers (2016)', 'Matrix, The (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 85
# Starting simulation with mood: Sadness
# 1586
# [2.503797]
# Simulated feedback for 'G.I. Jane (1997)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['G.I. Jane (1997)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 86
# Starting simulation with mood: Sadness
# 140850
# [1.3259383]
# Simulated feedback for 'Every Secret Thing (2014)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Every Secret Thing (2014)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 87
# Starting simulation with mood: Fear
# 62836
# [4.130866]
# Simulated feedback for 'Babylon 5: The Lost Tales - Voices in the Dark (2007)': Perfect
# User found the perfect movie: Babylon 5: The Lost Tales - Voices in the Dark (2007)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Babylon 5: The Lost Tales - Voices in the Dark (2007)']
# ['Perfect']
#
# Simulating experience for User ID: 88
# Starting simulation with mood: Anger
# 55118
# [4.473142]
# Simulated feedback for 'Eastern Promises (2007)': Perfect
# User found the perfect movie: Eastern Promises (2007)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Eastern Promises (2007)']
# ['Perfect']
#
# Simulating experience for User ID: 89
# Starting simulation with mood: Fear
# 138610
# [0.56251764]
# Simulated feedback for 'The Gallows (2015)': Dislike
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['The Gallows (2015)', 'Matrix, The (1999)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 90
# Starting simulation with mood: Disgust
# 1004
# [2.5382323]
# Simulated feedback for 'Glimmer Man, The (1996)': Dislike
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Glimmer Man, The (1996)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 91
# Starting simulation with mood: Fear
# 133782
# [1.1575407]
# Simulated feedback for 'Maggie (2015)': Dislike
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Maggie (2015)', 'Matrix, The (1999)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 92
# Starting simulation with mood: Disgust
# 104241
# [3.2530622]
# Simulated feedback for 'Kick-Ass 2 (2013)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Kick-Ass 2 (2013)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 93
# Starting simulation with mood: Anger
# 193565
# [3.3092196]
# Simulated feedback for 'Gintama: The Movie (2010)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Gintama: The Movie (2010)', 'Sneakers (1992)', 'Shawshank Redemption, The (1994)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 94
# Starting simulation with mood: Fear
# 65601
# [1.5257004]
# Simulated feedback for 'My Bloody Valentine 3-D (2009)': Dislike
# New rating added.
# 2571
# [4.196112]
# Simulated feedback for 'Matrix, The (1999)': Perfect
# User found the perfect movie: Matrix, The (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['My Bloody Valentine 3-D (2009)', 'Matrix, The (1999)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 95
# Starting simulation with mood: Sadness
# 118702
# [2.5500152]
# Simulated feedback for 'Unbroken (2014)': Dislike
# New rating added.
# 1259
# [4.3199825]
# Simulated feedback for 'Stand by Me (1986)': Perfect
# User found the perfect movie: Stand by Me (1986)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Unbroken (2014)', 'Stand by Me (1986)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 96
# Starting simulation with mood: Anger
# 75813
# [3.0653138]
# Simulated feedback for 'Leaves of Grass (2009)': Like
# New rating added.
# 1396
# [3.395031]
# Simulated feedback for 'Sneakers (1992)': Like
# New rating added.
# 318
# [4.0990586]
# Simulated feedback for 'Shawshank Redemption, The (1994)': Perfect
# User found the perfect movie: Shawshank Redemption, The (1994)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ...
# 1590
# [3.06355]
# Simulated feedback for 'Event Horizon (1997)': Like
# 207
# [3.2195754]
# Simulated feedback for 'Walk in the Clouds, A (1995)': Like
# 934
# [3.2198427]
# Simulated feedback for 'Father of the Bride (1950)': Like
# 181
# [2.1638143]
# Simulated feedback for 'Mighty Morphin Power Rangers: The Movie (1995)': Dislike
# 1037
# [3.037828]
# Simulated feedback for 'Lawnmower Man, The (1992)': Like
# 7099
# [4.217316]
# Simulated feedback for 'Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984)': Perfect
# User found the perfect movie: Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984)
#
# Simulation Summary:
# Total recommendations made: 7
# No perfect recommendation found during the simulation.
# ['Sandlot, The (1993)', 'Event Horizon (1997)', 'Walk in the Clouds, A (1995)', 'Father of the Bride (1950)', 'Mighty Morphin Power Rangers: The Movie (1995)', 'Lawnmower Man, The (1992)', 'Nausicaä of the Valley of the Wind (Kaze no tani no Naushika) (1984)']
# ['Like', 'Like', 'Like', 'Like', 'Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 588
# Starting simulation with mood: Fear
# 52973
# [3.6272283]
# Simulated feedback for 'Knocked Up (2007)': Like
# 122918
# [4.1010966]
# Simulated feedback for 'Guardians of the Galaxy 2 (2017)': Perfect
# User found the perfect movie: Guardians of the Galaxy 2 (2017)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Knocked Up (2007)', 'Guardians of the Galaxy 2 (2017)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 589
# Starting simulation with mood: Anger
# 4041
# [3.606253]
# Simulated feedback for 'Officer and a Gentleman, An (1982)': Like
# 4887
# [2.9600806]
# Simulated feedback for 'One, The (2001)': Like
# 349
# [3.512178]
# Simulated feedback for 'Clear and Present Danger (1994)': Like
# 2321
# [3.1702895]
# Simulated feedback for 'Pleasantville (1998)': Like
# 6709
# [3.0953848]
# Simulated feedback for 'Once Upon a Time in Mexico (2003)': Like
# 3617
# [3.2549422]
# Simulated feedback for 'Road Trip (2000)': Like
# 40278
# [3.5606666]
# Simulated feedback for 'Jarhead (2005)': Like
# 926
# [4.455383]
# Simulated feedback for 'All About Eve (1950)': Perfect
# User found the perfect movie: All About Eve (1950)
#
# Simulation Summary:
# Total recommendations made: 8
# No perfect recommendation found during the simulation.
# ['Officer and a Gentleman, An (1982)', 'One, The (2001)', 'Clear and Present Danger (1994)', 'Pleasantville (1998)', 'Once Upon a Time in Mexico (2003)', 'Road Trip (2000)', 'Jarhead (2005)', 'All About Eve (1950)']
# ['Like', 'Like', 'Like', 'Like', 'Like', 'Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 590
# Starting simulation with mood: Disgust
# 2253
# [2.4974473]
# Simulated feedback for 'Toys (1992)': Dislike
# 2140
# [3.071475]
# Simulated feedback for 'Dark Crystal, The (1982)': Like
# 68135
# [3.520399]
# Simulated feedback for '17 Again (2009)': Like
# 1833
# [3.081096]
# Simulated feedback for 'Mercury Rising (1998)': Like
# 3037
# [3.9090517]
# Simulated feedback for 'Little Big Man (1970)': Perfect
# User found the perfect movie: Little Big Man (1970)
#
# Simulation Summary:
# Total recommendations made: 5
# No perfect recommendation found during the simulation.
# ['Toys (1992)', 'Dark Crystal, The (1982)', '17 Again (2009)', 'Mercury Rising (1998)', 'Little Big Man (1970)']
# ['Dislike', 'Like', 'Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 591
# Starting simulation with mood: Anger
# 6958
# [2.6669183]
# Simulated feedback for 'Haunted Mansion, The (2003)': Dislike
# 93510
# [4.2202506]
# Simulated feedback for '21 Jump Street (2012)': Perfect
# User found the perfect movie: 21 Jump Street (2012)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Haunted Mansion, The (2003)', '21 Jump Street (2012)']
# ['Dislike', 'Perfect']
#
# Simulating experience for User ID: 592
# Starting simulation with mood: Sadness
# 663
# [2.712111]
# Simulated feedback for 'Kids in the Hall: Brain Candy (1996)': Dislike
# 45950
# [3.5532086]
# Simulated feedback for 'Inconvenient Truth, An (2006)': Like
# 1219
# [4.1801114]
# Simulated feedback for 'Psycho (1960)': Perfect
# User found the perfect movie: Psycho (1960)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Kids in the Hall: Brain Candy (1996)', 'Inconvenient Truth, An (2006)', 'Psycho (1960)']
# ['Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 593
# Starting simulation with mood: Sadness
# 2413
# [3.4700804]
# Simulated feedback for 'Clue (1985)': Like
# 339
# [3.403092]
# Simulated feedback for 'While You Were Sleeping (1995)': Like
# 1573
# [3.3364613]
# Simulated feedback for 'Face/Off (1997)': Like
# 112175
# [3.8910894]
# Simulated feedback for 'How to Train Your Dragon 2 (2014)': Perfect
# User found the perfect movie: How to Train Your Dragon 2 (2014)
#
# Simulation Summary:
# Total recommendations made: 4
# No perfect recommendation found during the simulation.
# ['Clue (1985)', 'While You Were Sleeping (1995)', 'Face/Off (1997)', 'How to Train Your Dragon 2 (2014)']
# ['Like', 'Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 594
# Starting simulation with mood: Joy
# 809
# [2.4045153]
# Simulated feedback for 'Fled (1996)': Dislike
# 742
# [2.4563308]
# Simulated feedback for 'Thinner (1996)': Dislike
# 348
# [3.2457104]
# Simulated feedback for 'Bullets Over Broadway (1994)': Like
# 112171
# [2.8288789]
# Simulated feedback for 'Equalizer, The (2014)': Like
# 1779
# [2.5467498]
# Simulated feedback for 'Sphere (1998)': Dislike
# 1175
# [3.8823836]
# Simulated feedback for 'Delicatessen (1991)': Perfect
# User found the perfect movie: Delicatessen (1991)
#
# Simulation Summary:
# Total recommendations made: 6
# No perfect recommendation found during the simulation.
# ['Fled (1996)', 'Thinner (1996)', 'Bullets Over Broadway (1994)', 'Equalizer, The (2014)', 'Sphere (1998)', 'Delicatessen (1991)']
# ['Dislike', 'Dislike', 'Like', 'Like', 'Dislike', 'Perfect']
#
# Simulating experience for User ID: 595
# Starting simulation with mood: Sadness
# 1963
# [2.823715]
# Simulated feedback for 'Take the Money and Run (1969)': Like
# 920
# [3.8702092]
# Simulated feedback for 'Gone with the Wind (1939)': Perfect
# User found the perfect movie: Gone with the Wind (1939)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Take the Money and Run (1969)', 'Gone with the Wind (1939)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 596
# Starting simulation with mood: Sadness
# 65230
# [2.8229587]
# Simulated feedback for 'Marley & Me (2008)': Like
# 3328
# [4.342121]
# Simulated feedback for 'Ghost Dog: The Way of the Samurai (1999)': Perfect
# User found the perfect movie: Ghost Dog: The Way of the Samurai (1999)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Marley & Me (2008)', 'Ghost Dog: The Way of the Samurai (1999)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 597
# Starting simulation with mood: Fear
# 122924
# [2.8767715]
# Simulated feedback for 'X-Men: Apocalypse (2016)': Like
# 87869
# [3.5233798]
# Simulated feedback for 'Horrible Bosses (2011)': Like
# 1131
# [4.154206]
# Simulated feedback for 'Jean de Florette (1986)': Perfect
# User found the perfect movie: Jean de Florette (1986)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['X-Men: Apocalypse (2016)', 'Horrible Bosses (2011)', 'Jean de Florette (1986)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 598
# Starting simulation with mood: Fear
# 8972
# [3.4376352]
# Simulated feedback for 'National Treasure (2004)': Like
# 52722
# [3.2230048]
# Simulated feedback for 'Spider-Man 3 (2007)': Like
# 74795
# [3.4898646]
# Simulated feedback for 'Green Zone (2010)': Like
# 239
# [2.6870959]
# Simulated feedback for 'Goofy Movie, A (1995)': Dislike
# 2539
# [3.0917003]
# Simulated feedback for 'Analyze This (1999)': Like
# 1013
# [2.6066086]
# Simulated feedback for 'Parent Trap, The (1961)': Dislike
# 50601
# [2.6026692]
# Simulated feedback for 'Bridge to Terabithia (2007)': Dislike
# 4128
# [3.9942968]
# Simulated feedback for 'Lost Boys, The (1987)': Perfect
# User found the perfect movie: Lost Boys, The (1987)
#
# Simulation Summary:
# Total recommendations made: 8
# No perfect recommendation found during the simulation.
# ['National Treasure (2004)', 'Spider-Man 3 (2007)', 'Green Zone (2010)', 'Goofy Movie, A (1995)', 'Analyze This (1999)', 'Parent Trap, The (1961)', 'Bridge to Terabithia (2007)', 'Lost Boys, The (1987)']
# ['Like', 'Like', 'Like', 'Dislike', 'Like', 'Dislike', 'Dislike', 'Perfect']
#
# Simulating experience for User ID: 599
# Starting simulation with mood: Fear
# 4369
# [3.1423028]
# Simulated feedback for 'Fast and the Furious, The (2001)': Like
# 5152
# [3.4359004]
# Simulated feedback for 'We Were Soldiers (2002)': Like
# 3246
# [4.572879]
# Simulated feedback for 'Malcolm X (1992)': Perfect
# User found the perfect movie: Malcolm X (1992)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Fast and the Furious, The (2001)', 'We Were Soldiers (2002)', 'Malcolm X (1992)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 600
# Starting simulation with mood: Anger
# 63131
# [4.009234]
# Simulated feedback for 'Role Models (2008)': Perfect
# User found the perfect movie: Role Models (2008)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ['Role Models (2008)']
# ['Perfect']
#
# Simulating experience for User ID: 601
# Starting simulation with mood: Joy
# 1297
# [3.4848063]
# Simulated feedback for 'Real Genius (1985)': Like
# 4878
# [3.7742817]
# Simulated feedback for 'Donnie Darko (2001)': Like
# 3178
# [3.4111884]
# Simulated feedback for 'Hurricane, The (1999)': Like
# 2793
# [1.5523659]
# Simulated feedback for 'American Werewolf in Paris, An (1997)': Dislike
# 142488
# [4.108611]
# Simulated feedback for 'Spotlight (2015)': Perfect
# User found the perfect movie: Spotlight (2015)
#
# Simulation Summary:
# Total recommendations made: 5
# No perfect recommendation found during the simulation.
# ['Real Genius (1985)', 'Donnie Darko (2001)', 'Hurricane, The (1999)', 'American Werewolf in Paris, An (1997)', 'Spotlight (2015)']
# ['Like', 'Like', 'Like', 'Dislike', 'Perfect']
#
# Simulating experience for User ID: 602
# Starting simulation with mood: Disgust
# 337
# [3.961751]
# Simulated feedback for 'What's Eating Gilbert Grape (1993)': Perfect
# User found the perfect movie: What's Eating Gilbert Grape (1993)
#
# Simulation Summary:
# Total recommendations made: 1
# No perfect recommendation found during the simulation.
# ["What's Eating Gilbert Grape (1993)"]
# ['Perfect']
#
# Simulating experience for User ID: 603
# Starting simulation with mood: Fear
# 4153
# [2.3427172]
# Simulated feedback for 'Down to Earth (2001)': Dislike
# 5621
# [2.6215997]
# Simulated feedback for 'Tuxedo, The (2002)': Dislike
# 2804
# [4.341306]
# Simulated feedback for 'Christmas Story, A (1983)': Perfect
# User found the perfect movie: Christmas Story, A (1983)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Down to Earth (2001)', 'Tuxedo, The (2002)', 'Christmas Story, A (1983)']
# ['Dislike', 'Dislike', 'Perfect']
#
# Simulating experience for User ID: 604
# Starting simulation with mood: Anger
# 8361
# [3.187589]
# Simulated feedback for 'Day After Tomorrow, The (2004)': Like
# 420
# [2.319583]
# Simulated feedback for 'Beverly Hills Cop III (1994)': Dislike
# 52975
# [3.2950785]
# Simulated feedback for 'Hairspray (2007)': Like
# 3897
# [4.1524687]
# Simulated feedback for 'Almost Famous (2000)': Perfect
# User found the perfect movie: Almost Famous (2000)
#
# Simulation Summary:
# Total recommendations made: 4
# No perfect recommendation found during the simulation.
# ['Day After Tomorrow, The (2004)', 'Beverly Hills Cop III (1994)', 'Hairspray (2007)', 'Almost Famous (2000)']
# ['Like', 'Dislike', 'Like', 'Perfect']
#
# Simulating experience for User ID: 605
# Starting simulation with mood: Anger
# 4005
# [3.087391]
# Simulated feedback for 'Living Daylights, The (1987)': Like
# 412
# [3.437795]
# Simulated feedback for 'Age of Innocence, The (1993)': Like
# 8874
# [3.9900274]
# Simulated feedback for 'Shaun of the Dead (2004)': Perfect
# User found the perfect movie: Shaun of the Dead (2004)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Living Daylights, The (1987)', 'Age of Innocence, The (1993)', 'Shaun of the Dead (2004)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 606
# Starting simulation with mood: Disgust
# 2993
# [3.6251087]
# Simulated feedback for 'Thunderball (1965)': Like
# 73321
# [3.281569]
# Simulated feedback for 'Book of Eli, The (2010)': Like
# 1301
# [3.6888742]
# Simulated feedback for 'Forbidden Planet (1956)': Like
# 4280
# [3.465841]
# Simulated feedback for 'World According to Garp, The (1982)': Like
# 79091
# [3.684447]
# Simulated feedback for 'Despicable Me (2010)': Like
# 31658
# [4.3731103]
# Simulated feedback for 'Howl's Moving Castle (Hauru no ugoku shiro) (2004)': Perfect
# User found the perfect movie: Howl's Moving Castle (Hauru no ugoku shiro) (2004)
#
# Simulation Summary:
# Total recommendations made: 6
# No perfect recommendation found during the simulation.
# ['Thunderball (1965)', 'Book of Eli, The (2010)', 'Forbidden Planet (1956)', 'World According to Garp, The (1982)', 'Despicable Me (2010)', "Howl's Moving Castle (Hauru no ugoku shiro) (2004)"]
# ['Like', 'Like', 'Like', 'Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 607
# Starting simulation with mood: Joy
# 6753
# [3.2127798]
# Simulated feedback for 'Secondhand Lions (2003)': Like
# 1242
# [4.339091]
# Simulated feedback for 'Glory (1989)': Perfect
# User found the perfect movie: Glory (1989)
#
# Simulation Summary:
# Total recommendations made: 2
# No perfect recommendation found during the simulation.
# ['Secondhand Lions (2003)', 'Glory (1989)']
# ['Like', 'Perfect']
#
# Simulating experience for User ID: 608
# Starting simulation with mood: Anger
# 5349
# [3.611013]
# Simulated feedback for 'Spider-Man (2002)': Like
# 68793
# [3.242603]
# Simulated feedback for 'Night at the Museum: Battle of the Smithsonian (2009)': Like
# 97304
# [3.9411523]
# Simulated feedback for 'Argo (2012)': Perfect
# User found the perfect movie: Argo (2012)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ['Spider-Man (2002)', 'Night at the Museum: Battle of the Smithsonian (2009)', 'Argo (2012)']
# ['Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 609
# Starting simulation with mood: Fear
# 7137
# [3.7622135]
# Simulated feedback for 'Cooler, The (2003)': Like
# 3044
# [3.7389996]
# Simulated feedback for 'Dead Again (1991)': Like
# 1078
# [3.1698332]
# Simulated feedback for 'Bananas (1971)': Like
# 2605
# [3.025752]
# Simulated feedback for 'Entrapment (1999)': Like
# 1833
# [3.081096]
# Simulated feedback for 'Mercury Rising (1998)': Like
# 2268
# [3.9907403]
# Simulated feedback for 'Few Good Men, A (1992)': Perfect
# User found the perfect movie: Few Good Men, A (1992)
#
# Simulation Summary:
# Total recommendations made: 6
# No perfect recommendation found during the simulation.
# ['Cooler, The (2003)', 'Dead Again (1991)', 'Bananas (1971)', 'Entrapment (1999)', 'Mercury Rising (1998)', 'Few Good Men, A (1992)']
# ['Like', 'Like', 'Like', 'Like', 'Like', 'Perfect']
#
# Simulating experience for User ID: 610
# Starting simulation with mood: Fear
# 2468
# [2.3005288]
# Simulated feedback for 'Jumpin' Jack Flash (1986)': Dislike
# 3798
# [3.582538]
# Simulated feedback for 'What Lies Beneath (2000)': Like
# 98809
# [3.845628]
# Simulated feedback for 'Hobbit: An Unexpected Journey, The (2012)': Perfect
# User found the perfect movie: Hobbit: An Unexpected Journey, The (2012)
#
# Simulation Summary:
# Total recommendations made: 3
# No perfect recommendation found during the simulation.
# ["Jumpin' Jack Flash (1986)", 'What Lies Beneath (2000)', 'Hobbit: An Unexpected Journey, The (2012)']
# ['Dislike', 'Like', 'Perfect']
# All simulations completed. Results saved.
# All simulations completed. Results saved.
# All simulations completed. Results saved.
